# %% [markdown]
# # Load Data from Strava
# using segments as input files in this notebook I am gonna fetch data from Strava related to** efforts done** on the **input segments over 2017**.
#
# Furthermore, for each athlete who actually did an effort, we going to retrieve data.

# %%
import requests
import time
import pandas as pd
import numpy as np
import math
import os

# Configure OAuth2 access token for authorization: strava_oauth
access_token = os.environ.get('STRAVA_API_KEY', '') #please configure this env var with your STRAVA API KEY

# Strava base url
base_url = 'https://www.strava.com/api/v3'

#headers
headers = {'Authorization': 'Bearer ' + access_token}

#short term limit min * sec
short_term_limit = 15 * 60
max_no_req_short = 600
delay_short = short_term_limit / max_no_req_short

# %%
segments = pd.read_csv("strava-segments-italy-full.csv")

# %%
#load activities
num_done = 0
activities = pd.DataFrame()
batches = 200
index = 0

# %%
segments = segments.set_index("Unnamed: 0")

# %%
def load_activities(segment):
    endpoint = '/segments/{}/leaderboard'.format(segment)
    print(base_url + endpoint)
    payload = {}
    r = requests.get(base_url + endpoint, data = payload, headers=headers)
    num_efforts = r.json()["effort_count"]
    segment_id = pd.Series(segment for x in range(num_efforts))
    pages = math.ceil(num_efforts / 200)
    sum = pd.DataFrame()
    start = time.time()
    print("segment {}, num efforts {} pages {}".format(segment,num_efforts, pages))
    for p in range(1, pages + 1):
        time.sleep(delay_short + 0.02)
        payload = {'page': p,'per_page': 200}
        r = requests.get(base_url + endpoint, data = payload, headers=headers)
        try:
            df = pd.DataFrame(r.json()["entries"])
            sum = sum.append(df, ignore_index=True)
        except KeyError as k:
            print("no entries found")
        #rank = df.iloc[0]["rank"]
        #print("page {}, start rank {}".format(p, rank))
    #print("shape {}".format(sum.shape))
    sum["segment"] = segment_id
    print("total time {:.2f} min".format((time.time() - start) / 60))
    return sum

for seg in segments.loc[:]["id"].values:#5378646
    time.sleep(delay_short + 0.02)
    actv = load_activities(seg)
    num_done = num_done + 1
    print("Num done {}".format(num_done))
    activities = activities.append(actv, ignore_index=True)
    if num_done >= batches:
        activities.to_csv(path_or_buf="strava-activities-italy-full-{}.csv".format(index),index=True)
        activities = pd.DataFrame()
        index += 1
        num_done = 0
# Out:
# https://www.strava.com/api/v3/segments/7033907/leaderboard
# segment 7033907, num efforts 2950 pages 15
# total time 0.66 min
# Num done 1
# https://www.strava.com/api/v3/segments/5293297/leaderboard
# segment 5293297, num efforts 2950 pages 15
# total time 0.66 min
# Num done 2
# https://www.strava.com/api/v3/segments/8400005/leaderboard
# segment 8400005, num efforts 699 pages 4
# total time 0.18 min
# Num done 3
# https://www.strava.com/api/v3/segments/1197573/leaderboard
# segment 1197573, num efforts 2746 pages 14
# total time 0.71 min
# Num done 4
# https://www.strava.com/api/v3/segments/4620026/leaderboard
# segment 4620026, num efforts 642 pages 4
# total time 0.19 min
# Num done 5
# https://www.strava.com/api/v3/segments/6833753/leaderboard
# segment 6833753, num efforts 628 pages 4
# total time 0.16 min
# Num done 6
# https://www.strava.com/api/v3/segments/1282316/leaderboard
# segment 1282316, num efforts 2551 pages 13
# total time 0.69 min
# Num done 7
# https://www.strava.com/api/v3/segments/852535/leaderboard
# segment 852535, num efforts 2381 pages 12
# total time 0.56 min
# Num done 8
# https://www.strava.com/api/v3/segments/4165191/leaderboard
# segment 4165191, num efforts 5596 pages 28
# total time 1.26 min
# Num done 9
# https://www.strava.com/api/v3/segments/6695531/leaderboard
# segment 6695531, num efforts 5339 pages 27
# total time 1.11 min
# Num done 10
# https://www.strava.com/api/v3/segments/763322/leaderboard
# segment 763322, num efforts 2220 pages 12
# total time 0.45 min
# Num done 11
# https://www.strava.com/api/v3/segments/14128873/leaderboard
# segment 14128873, num efforts 2433 pages 13
# total time 0.51 min
# Num done 12
# https://www.strava.com/api/v3/segments/1142140/leaderboard
# segment 1142140, num efforts 3836 pages 20
# total time 0.87 min
# Num done 13
# https://www.strava.com/api/v3/segments/10554871/leaderboard
# segment 10554871, num efforts 6074 pages 31
# total time 1.33 min
# Num done 14
# https://www.strava.com/api/v3/segments/6932114/leaderboard
# segment 6932114, num efforts 3360 pages 17
# total time 0.71 min
# Num done 15
# https://www.strava.com/api/v3/segments/2696509/leaderboard
# segment 2696509, num efforts 905 pages 5
# total time 0.20 min
# Num done 16
# https://www.strava.com/api/v3/segments/5912151/leaderboard
# segment 5912151, num efforts 902 pages 5
# total time 0.20 min
# Num done 17
# https://www.strava.com/api/v3/segments/5182023/leaderboard
# segment 5182023, num efforts 475 pages 3
# total time 0.12 min
# Num done 18
# https://www.strava.com/api/v3/segments/8458512/leaderboard
# segment 8458512, num efforts 1783 pages 9
# total time 0.37 min
# Num done 19
# https://www.strava.com/api/v3/segments/1257512/leaderboard
# segment 1257512, num efforts 583 pages 3
# total time 0.13 min
# Num done 20
# https://www.strava.com/api/v3/segments/16689854/leaderboard
# segment 16689854, num efforts 333 pages 2
# total time 0.08 min
# Num done 21
# https://www.strava.com/api/v3/segments/3624197/leaderboard
# segment 3624197, num efforts 335 pages 2
# total time 0.08 min
# Num done 22
# https://www.strava.com/api/v3/segments/14511742/leaderboard
# segment 14511742, num efforts 885 pages 5
# total time 0.19 min
# Num done 23
# https://www.strava.com/api/v3/segments/826837/leaderboard
# segment 826837, num efforts 4716 pages 24
# total time 1.10 min
# Num done 24
# https://www.strava.com/api/v3/segments/8770780/leaderboard
# segment 8770780, num efforts 4225 pages 22
# total time 0.96 min
# Num done 25
# https://www.strava.com/api/v3/segments/1699314/leaderboard
# segment 1699314, num efforts 3177 pages 16
# total time 0.72 min
# Num done 26
# https://www.strava.com/api/v3/segments/8603747/leaderboard
# segment 8603747, num efforts 1168 pages 6
# total time 0.25 min
# Num done 27
# https://www.strava.com/api/v3/segments/1514299/leaderboard
# segment 1514299, num efforts 519 pages 3
# total time 0.12 min
# Num done 28
# https://www.strava.com/api/v3/segments/4737827/leaderboard
# segment 4737827, num efforts 960 pages 5
# total time 0.21 min
# Num done 29
# https://www.strava.com/api/v3/segments/5797827/leaderboard
# segment 5797827, num efforts 503 pages 3
# total time 0.14 min
# Num done 30
# https://www.strava.com/api/v3/segments/12055776/leaderboard
# segment 12055776, num efforts 485 pages 3
# total time 0.12 min
# Num done 31
# https://www.strava.com/api/v3/segments/3972139/leaderboard
# segment 3972139, num efforts 344 pages 2
# total time 0.08 min
# Num done 32
# https://www.strava.com/api/v3/segments/14453775/leaderboard
# segment 14453775, num efforts 73 pages 1
# total time 0.03 min
# Num done 33
# https://www.strava.com/api/v3/segments/5822468/leaderboard
# segment 5822468, num efforts 499 pages 3
# total time 0.12 min
# Num done 34
# https://www.strava.com/api/v3/segments/10318011/leaderboard
# segment 10318011, num efforts 80 pages 1
# total time 0.03 min
# Num done 35
# https://www.strava.com/api/v3/segments/3829299/leaderboard
# segment 3829299, num efforts 12 pages 1
# total time 0.03 min
# Num done 36
# https://www.strava.com/api/v3/segments/5682666/leaderboard
# segment 5682666, num efforts 15 pages 1
# total time 0.03 min
# Num done 37
# https://www.strava.com/api/v3/segments/7407551/leaderboard
# segment 7407551, num efforts 25 pages 1
# total time 0.03 min
# Num done 38
# https://www.strava.com/api/v3/segments/5299305/leaderboard
# segment 5299305, num efforts 10 pages 1
# total time 0.03 min
# Num done 39
# https://www.strava.com/api/v3/segments/4811483/leaderboard
# segment 4811483, num efforts 366 pages 2
# total time 0.08 min
# Num done 40
# https://www.strava.com/api/v3/segments/11299020/leaderboard
# segment 11299020, num efforts 217 pages 2
# total time 0.07 min
# Num done 41
# https://www.strava.com/api/v3/segments/14173483/leaderboard
# segment 14173483, num efforts 17 pages 1
# total time 0.03 min
# Num done 42
# https://www.strava.com/api/v3/segments/9131739/leaderboard
# segment 9131739, num efforts 13 pages 1
# total time 0.03 min
# Num done 43
# https://www.strava.com/api/v3/segments/1767673/leaderboard
# segment 1767673, num efforts 316 pages 2
# total time 0.07 min
# Num done 44
# https://www.strava.com/api/v3/segments/7533032/leaderboard
# segment 7533032, num efforts 315 pages 2
# total time 0.07 min
# Num done 45
# https://www.strava.com/api/v3/segments/6579133/leaderboard
# segment 6579133, num efforts 69 pages 1
# total time 0.03 min
# Num done 46
# https://www.strava.com/api/v3/segments/2430961/leaderboard
# segment 2430961, num efforts 263 pages 2
# total time 0.07 min
# Num done 47
# https://www.strava.com/api/v3/segments/5783265/leaderboard
# segment 5783265, num efforts 173 pages 1
# total time 0.04 min
# Num done 48
# https://www.strava.com/api/v3/segments/6121881/leaderboard
# segment 6121881, num efforts 356 pages 2
# total time 0.08 min
# Num done 49
# https://www.strava.com/api/v3/segments/2430962/leaderboard
# segment 2430962, num efforts 263 pages 2
# total time 0.07 min
# Num done 50
# https://www.strava.com/api/v3/segments/17523322/leaderboard
# segment 17523322, num efforts 314 pages 2
# total time 0.07 min
# Num done 51
# https://www.strava.com/api/v3/segments/3487559/leaderboard
# segment 3487559, num efforts 527 pages 3
# total time 0.12 min
# Num done 52
# https://www.strava.com/api/v3/segments/15186865/leaderboard
# segment 15186865, num efforts 22 pages 1
# total time 0.03 min
# Num done 53
# https://www.strava.com/api/v3/segments/3684206/leaderboard
# segment 3684206, num efforts 22 pages 1
# total time 0.03 min
# Num done 54
# https://www.strava.com/api/v3/segments/3684205/leaderboard
# segment 3684205, num efforts 22 pages 1
# total time 0.03 min
# Num done 55
# https://www.strava.com/api/v3/segments/3686608/leaderboard
# segment 3686608, num efforts 22 pages 1
# total time 0.03 min
# Num done 56
# https://www.strava.com/api/v3/segments/3536915/leaderboard
# segment 3536915, num efforts 225 pages 2
# total time 0.07 min
# Num done 57
# https://www.strava.com/api/v3/segments/9826086/leaderboard
# segment 9826086, num efforts 82 pages 1
# total time 0.03 min
# Num done 58
# https://www.strava.com/api/v3/segments/4774964/leaderboard
# segment 4774964, num efforts 76 pages 1
# total time 0.03 min
# Num done 59
# https://www.strava.com/api/v3/segments/9826045/leaderboard
# segment 9826045, num efforts 82 pages 1
# total time 0.03 min
# Num done 60
# https://www.strava.com/api/v3/segments/13108631/leaderboard
# segment 13108631, num efforts 36 pages 1
# total time 0.03 min
# Num done 61
# https://www.strava.com/api/v3/segments/5977130/leaderboard
# segment 5977130, num efforts 38 pages 1
# total time 0.03 min
# Num done 62
# https://www.strava.com/api/v3/segments/4496139/leaderboard
# segment 4496139, num efforts 14 pages 1
# total time 0.03 min
# Num done 63
# https://www.strava.com/api/v3/segments/10027197/leaderboard
# segment 10027197, num efforts 25 pages 1
# total time 0.03 min
# Num done 64
# https://www.strava.com/api/v3/segments/15781097/leaderboard
# segment 15781097, num efforts 26 pages 1
# total time 0.03 min
# Num done 65
# https://www.strava.com/api/v3/segments/10027217/leaderboard
# segment 10027217, num efforts 26 pages 1
# total time 0.03 min
# Num done 66
# https://www.strava.com/api/v3/segments/2394040/leaderboard
# segment 2394040, num efforts 119 pages 1
# total time 0.04 min
# Num done 67
# https://www.strava.com/api/v3/segments/2394041/leaderboard
# segment 2394041, num efforts 120 pages 1
# total time 0.03 min
# Num done 68
# https://www.strava.com/api/v3/segments/4486904/leaderboard
# segment 4486904, num efforts 3364 pages 17
# total time 0.75 min
# Num done 69
# https://www.strava.com/api/v3/segments/8290499/leaderboard
# segment 8290499, num efforts 1023 pages 6
# total time 0.24 min
# Num done 70
# https://www.strava.com/api/v3/segments/4939103/leaderboard
# segment 4939103, num efforts 232 pages 2
# total time 0.07 min
# Num done 71
# https://www.strava.com/api/v3/segments/5485594/leaderboard
# segment 5485594, num efforts 179 pages 1
# total time 0.04 min
# Num done 72
# https://www.strava.com/api/v3/segments/5317236/leaderboard
# segment 5317236, num efforts 80 pages 1
# total time 0.03 min
# Num done 73
# https://www.strava.com/api/v3/segments/5296461/leaderboard
# segment 5296461, num efforts 242 pages 2
# total time 0.06 min
# Num done 74
# https://www.strava.com/api/v3/segments/12331740/leaderboard
# segment 12331740, num efforts 40 pages 1
# total time 0.03 min
# Num done 75
# https://www.strava.com/api/v3/segments/7896571/leaderboard
# segment 7896571, num efforts 82 pages 1
# total time 0.03 min
# Num done 76
# https://www.strava.com/api/v3/segments/17824349/leaderboard
# segment 17824349, num efforts 24 pages 1
# total time 0.03 min
# Num done 77
# https://www.strava.com/api/v3/segments/7920222/leaderboard
# segment 7920222, num efforts 64 pages 1
# total time 0.03 min
# Num done 78
# https://www.strava.com/api/v3/segments/1560864/leaderboard
# segment 1560864, num efforts 1382 pages 7
# total time 0.29 min
# Num done 79
# https://www.strava.com/api/v3/segments/12347372/leaderboard
# segment 12347372, num efforts 1739 pages 9
# total time 0.37 min
# Num done 80
# https://www.strava.com/api/v3/segments/7021949/leaderboard
# segment 7021949, num efforts 86 pages 1
# total time 0.03 min
# Num done 81
# https://www.strava.com/api/v3/segments/2578597/leaderboard
# segment 2578597, num efforts 254 pages 2
# total time 0.08 min
# Num done 82
# https://www.strava.com/api/v3/segments/2492964/leaderboard
# segment 2492964, num efforts 415 pages 3
# total time 0.11 min
# Num done 83
# https://www.strava.com/api/v3/segments/15748284/leaderboard
# segment 15748284, num efforts 100 pages 1
# total time 0.03 min
# Num done 84
# https://www.strava.com/api/v3/segments/5577835/leaderboard
# segment 5577835, num efforts 29 pages 1
# total time 0.03 min
# Num done 85
# https://www.strava.com/api/v3/segments/5390755/leaderboard
# segment 5390755, num efforts 311 pages 2
# total time 0.08 min
# Num done 86
# https://www.strava.com/api/v3/segments/5412962/leaderboard
# segment 5412962, num efforts 256 pages 2
# total time 0.07 min
# Num done 87
# https://www.strava.com/api/v3/segments/13402922/leaderboard
# segment 13402922, num efforts 53 pages 1
# total time 0.03 min
# Num done 88
# https://www.strava.com/api/v3/segments/669345/leaderboard
# segment 669345, num efforts 2080 pages 11
# total time 0.45 min
# Num done 89
# https://www.strava.com/api/v3/segments/12451302/leaderboard
# segment 12451302, num efforts 2053 pages 11
# total time 0.43 min
# Num done 90
# https://www.strava.com/api/v3/segments/1271877/leaderboard
# segment 1271877, num efforts 2151 pages 11
# total time 0.40 min
# Num done 91
# https://www.strava.com/api/v3/segments/2157862/leaderboard
# segment 2157862, num efforts 2243 pages 12
# total time 0.46 min
# Num done 92
# https://www.strava.com/api/v3/segments/2291680/leaderboard
# segment 2291680, num efforts 2133 pages 11
# total time 0.41 min
# Num done 93
# https://www.strava.com/api/v3/segments/2291683/leaderboard
# segment 2291683, num efforts 2201 pages 12
# total time 0.41 min
# Num done 94
# https://www.strava.com/api/v3/segments/14998940/leaderboard
# segment 14998940, num efforts 86 pages 1
# total time 0.03 min
# Num done 95
# https://www.strava.com/api/v3/segments/17924420/leaderboard
# segment 17924420, num efforts 46 pages 1
# total time 0.03 min
# Num done 96
# https://www.strava.com/api/v3/segments/5268597/leaderboard
# segment 5268597, num efforts 2093 pages 11
# total time 0.39 min
# Num done 97
# https://www.strava.com/api/v3/segments/3895070/leaderboard
# segment 3895070, num efforts 74 pages 1
# total time 0.03 min
# Num done 98
# https://www.strava.com/api/v3/segments/5463325/leaderboard
# segment 5463325, num efforts 337 pages 2
# total time 0.08 min
# Num done 99
# https://www.strava.com/api/v3/segments/5197189/leaderboard
# segment 5197189, num efforts 21 pages 1
# total time 0.03 min
# Num done 100
# https://www.strava.com/api/v3/segments/5917184/leaderboard
# segment 5917184, num efforts 24 pages 1
# total time 0.03 min
# Num done 101
# https://www.strava.com/api/v3/segments/5197214/leaderboard
# segment 5197214, num efforts 21 pages 1
# total time 0.03 min
# Num done 102
# https://www.strava.com/api/v3/segments/5209247/leaderboard
# segment 5209247, num efforts 13 pages 1
# total time 0.03 min
# Num done 103
# https://www.strava.com/api/v3/segments/5209246/leaderboard
# segment 5209246, num efforts 12 pages 1
# total time 0.03 min
# Num done 104
# https://www.strava.com/api/v3/segments/14710672/leaderboard
# segment 14710672, num efforts 21 pages 1
# total time 0.03 min
# Num done 105
# https://www.strava.com/api/v3/segments/1610199/leaderboard
# segment 1610199, num efforts 836 pages 5
# total time 0.20 min
# Num done 106
# https://www.strava.com/api/v3/segments/1961005/leaderboard
# segment 1961005, num efforts 869 pages 5
# total time 0.22 min
# Num done 107
# https://www.strava.com/api/v3/segments/1757127/leaderboard
# segment 1757127, num efforts 674 pages 4
# total time 0.16 min
# Num done 108
# https://www.strava.com/api/v3/segments/3258356/leaderboard
# segment 3258356, num efforts 854 pages 5
# total time 0.19 min
# Num done 109
# https://www.strava.com/api/v3/segments/1621372/leaderboard
# segment 1621372, num efforts 778 pages 4
# total time 0.16 min
# Num done 110
# https://www.strava.com/api/v3/segments/9831851/leaderboard
# segment 9831851, num efforts 696 pages 4
# total time 0.14 min
# Num done 111
# https://www.strava.com/api/v3/segments/5349909/leaderboard
# segment 5349909, num efforts 960 pages 5
# total time 0.17 min
# Num done 112
# https://www.strava.com/api/v3/segments/1631616/leaderboard
# segment 1631616, num efforts 477 pages 3
# total time 0.12 min
# Num done 113
# https://www.strava.com/api/v3/segments/4516695/leaderboard
# segment 4516695, num efforts 469 pages 3
# total time 0.12 min
# Num done 114
# https://www.strava.com/api/v3/segments/9529142/leaderboard
# segment 9529142, num efforts 49 pages 1
# total time 0.04 min
# Num done 115
# https://www.strava.com/api/v3/segments/3655594/leaderboard
# segment 3655594, num efforts 359 pages 2
# total time 0.08 min
# Num done 116
# https://www.strava.com/api/v3/segments/7945460/leaderboard
# segment 7945460, num efforts 110 pages 1
# total time 0.05 min
# Num done 117
# https://www.strava.com/api/v3/segments/5050117/leaderboard
# segment 5050117, num efforts 395 pages 2
# total time 0.07 min
# Num done 118
# https://www.strava.com/api/v3/segments/1185905/leaderboard
# segment 1185905, num efforts 421 pages 3
# total time 0.10 min
# Num done 119
# https://www.strava.com/api/v3/segments/1185904/leaderboard
# segment 1185904, num efforts 405 pages 3
# total time 0.10 min
# Num done 120
# https://www.strava.com/api/v3/segments/17712328/leaderboard
# segment 17712328, num efforts 30 pages 1
# total time 0.03 min
# Num done 121
# https://www.strava.com/api/v3/segments/17856757/leaderboard
# segment 17856757, num efforts 28 pages 1
# total time 0.03 min
# Num done 122
# https://www.strava.com/api/v3/segments/4763935/leaderboard
# segment 4763935, num efforts 253 pages 2
# total time 0.07 min
# Num done 123
# https://www.strava.com/api/v3/segments/3310586/leaderboard
# segment 3310586, num efforts 108 pages 1
# total time 0.03 min
# Num done 124
# https://www.strava.com/api/v3/segments/5728576/leaderboard
# segment 5728576, num efforts 153 pages 1
# total time 0.04 min
# Num done 125
# https://www.strava.com/api/v3/segments/5054410/leaderboard
# segment 5054410, num efforts 1951 pages 10
# total time 0.43 min
# Num done 126
# https://www.strava.com/api/v3/segments/1574572/leaderboard
# segment 1574572, num efforts 2018 pages 11
# total time 0.41 min
# Num done 127
# https://www.strava.com/api/v3/segments/2094185/leaderboard
# segment 2094185, num efforts 969 pages 5
# total time 0.21 min
# Num done 128
# https://www.strava.com/api/v3/segments/2094183/leaderboard
# segment 2094183, num efforts 963 pages 5
# total time 0.18 min
# Num done 129
# https://www.strava.com/api/v3/segments/2094181/leaderboard
# segment 2094181, num efforts 963 pages 5
# total time 0.18 min
# Num done 130
# https://www.strava.com/api/v3/segments/2094179/leaderboard
# segment 2094179, num efforts 968 pages 5
# total time 0.17 min
# Num done 131
# https://www.strava.com/api/v3/segments/9769938/leaderboard
# segment 9769938, num efforts 235 pages 2
# total time 0.07 min
# Num done 132
# https://www.strava.com/api/v3/segments/11163357/leaderboard
# segment 11163357, num efforts 24 pages 1
# total time 0.03 min
# Num done 133
# https://www.strava.com/api/v3/segments/7852859/leaderboard
# segment 7852859, num efforts 130 pages 1
# total time 0.03 min
# Num done 134
# https://www.strava.com/api/v3/segments/12965055/leaderboard
# segment 12965055, num efforts 131 pages 1
# total time 0.04 min
# Num done 135
# https://www.strava.com/api/v3/segments/7471751/leaderboard
# segment 7471751, num efforts 1649 pages 9
# total time 0.38 min
# Num done 136
# https://www.strava.com/api/v3/segments/1870183/leaderboard
# segment 1870183, num efforts 1676 pages 9
# total time 0.38 min
# Num done 137
# https://www.strava.com/api/v3/segments/3677550/leaderboard
# segment 3677550, num efforts 2746 pages 14
# total time 0.60 min
# Num done 138
# https://www.strava.com/api/v3/segments/8382242/leaderboard
# segment 8382242, num efforts 293 pages 2
# total time 0.08 min
# Num done 139
# https://www.strava.com/api/v3/segments/2136112/leaderboard
# segment 2136112, num efforts 2745 pages 14
# total time 0.53 min
# Num done 140
# https://www.strava.com/api/v3/segments/1634789/leaderboard
# segment 1634789, num efforts 1729 pages 9
# total time 0.33 min
# Num done 141
# https://www.strava.com/api/v3/segments/5057157/leaderboard
# segment 5057157, num efforts 450 pages 3
# total time 0.12 min
# Num done 142
# https://www.strava.com/api/v3/segments/12453043/leaderboard
# segment 12453043, num efforts 557 pages 3
# total time 0.12 min
# Num done 143
# https://www.strava.com/api/v3/segments/12578563/leaderboard
# segment 12578563, num efforts 511 pages 3
# total time 0.12 min
# Num done 144
# https://www.strava.com/api/v3/segments/941074/leaderboard
# segment 941074, num efforts 489 pages 3
# total time 0.12 min
# Num done 145
# https://www.strava.com/api/v3/segments/990477/leaderboard
# segment 990477, num efforts 2498 pages 13
# total time 0.56 min
# Num done 146
# https://www.strava.com/api/v3/segments/753729/leaderboard
# segment 753729, num efforts 2035 pages 11
# total time 0.46 min
# Num done 147
# https://www.strava.com/api/v3/segments/2294782/leaderboard
# segment 2294782, num efforts 2149 pages 11
# total time 0.42 min
# Num done 148
# https://www.strava.com/api/v3/segments/6159828/leaderboard
# segment 6159828, num efforts 460 pages 3
# total time 0.11 min
# Num done 149
# https://www.strava.com/api/v3/segments/5037049/leaderboard
# segment 5037049, num efforts 478 pages 3
# total time 0.10 min
# Num done 150
# https://www.strava.com/api/v3/segments/4281155/leaderboard
# segment 4281155, num efforts 417 pages 3
# total time 0.11 min
# Num done 151
# https://www.strava.com/api/v3/segments/3989149/leaderboard
# segment 3989149, num efforts 453 pages 3
# total time 0.10 min
# Num done 152
# https://www.strava.com/api/v3/segments/4539857/leaderboard
# segment 4539857, num efforts 526 pages 3
# total time 0.14 min
# Num done 153
# https://www.strava.com/api/v3/segments/1276103/leaderboard
# segment 1276103, num efforts 255 pages 2
# total time 0.06 min
# Num done 154
# https://www.strava.com/api/v3/segments/6600425/leaderboard
# segment 6600425, num efforts 51 pages 1
# total time 0.03 min
# Num done 155
# https://www.strava.com/api/v3/segments/694893/leaderboard
# segment 694893, num efforts 2674 pages 14
# total time 0.58 min
# Num done 156
# https://www.strava.com/api/v3/segments/2553274/leaderboard
# segment 2553274, num efforts 2178 pages 11
# total time 0.46 min
# Num done 157
# https://www.strava.com/api/v3/segments/5247507/leaderboard
# segment 5247507, num efforts 2808 pages 15
# total time 0.58 min
# Num done 158
# https://www.strava.com/api/v3/segments/2539721/leaderboard
# segment 2539721, num efforts 639 pages 4
# total time 0.16 min
# Num done 159
# https://www.strava.com/api/v3/segments/1248333/leaderboard
# segment 1248333, num efforts 2332 pages 12
# total time 0.50 min
# Num done 160
# https://www.strava.com/api/v3/segments/753717/leaderboard
# segment 753717, num efforts 552 pages 3
# total time 0.12 min
# Num done 161
# https://www.strava.com/api/v3/segments/8106995/leaderboard
# segment 8106995, num efforts 589 pages 3
# total time 0.13 min
# Num done 162
# https://www.strava.com/api/v3/segments/2484365/leaderboard
# segment 2484365, num efforts 978 pages 5
# total time 0.22 min
# Num done 163
# https://www.strava.com/api/v3/segments/1301328/leaderboard
# segment 1301328, num efforts 321 pages 2
# total time 0.08 min
# Num done 164
# https://www.strava.com/api/v3/segments/5522814/leaderboard
# segment 5522814, num efforts 799 pages 4
# total time 0.16 min
# Num done 165
# https://www.strava.com/api/v3/segments/5441284/leaderboard
# segment 5441284, num efforts 1506 pages 8
# total time 0.34 min
# Num done 166
# https://www.strava.com/api/v3/segments/7608574/leaderboard
# segment 7608574, num efforts 1946 pages 10
# total time 0.44 min
# Num done 167
# https://www.strava.com/api/v3/segments/13107729/leaderboard
# segment 13107729, num efforts 1938 pages 10
# total time 0.40 min
# Num done 168
# https://www.strava.com/api/v3/segments/7789320/leaderboard
# segment 7789320, num efforts 1749 pages 9
# total time 0.37 min
# Num done 169
# https://www.strava.com/api/v3/segments/7645730/leaderboard
# segment 7645730, num efforts 2003 pages 11
# total time 0.39 min
# Num done 170
# https://www.strava.com/api/v3/segments/2556535/leaderboard
# segment 2556535, num efforts 843 pages 5
# total time 0.20 min
# Num done 171
# https://www.strava.com/api/v3/segments/11683144/leaderboard
# segment 11683144, num efforts 1270 pages 7
# total time 0.27 min
# Num done 172
# https://www.strava.com/api/v3/segments/1287232/leaderboard
# segment 1287232, num efforts 1105 pages 6
# total time 0.24 min
# Num done 173
# https://www.strava.com/api/v3/segments/1432599/leaderboard
# segment 1432599, num efforts 214 pages 2
# total time 0.07 min
# Num done 174
# https://www.strava.com/api/v3/segments/15804854/leaderboard
# segment 15804854, num efforts 663 pages 4
# total time 0.14 min
# Num done 175
# https://www.strava.com/api/v3/segments/1734253/leaderboard
# segment 1734253, num efforts 244 pages 2
# total time 0.07 min
# Num done 176
# https://www.strava.com/api/v3/segments/1782542/leaderboard
# segment 1782542, num efforts 161 pages 1
# total time 0.04 min
# Num done 177
# https://www.strava.com/api/v3/segments/1734251/leaderboard
# segment 1734251, num efforts 224 pages 2
# total time 0.07 min
# Num done 178
# https://www.strava.com/api/v3/segments/16204903/leaderboard
# segment 16204903, num efforts 545 pages 3
# total time 0.12 min
# Num done 179
# https://www.strava.com/api/v3/segments/1695234/leaderboard
# segment 1695234, num efforts 716 pages 4
# total time 0.17 min
# Num done 180
# https://www.strava.com/api/v3/segments/7333883/leaderboard
# segment 7333883, num efforts 365 pages 2
# total time 0.08 min
# Num done 181
# https://www.strava.com/api/v3/segments/4924486/leaderboard
# segment 4924486, num efforts 550 pages 3
# total time 0.11 min
# Num done 182
# https://www.strava.com/api/v3/segments/4924487/leaderboard
# segment 4924487, num efforts 548 pages 3
# total time 0.11 min
# Num done 183
# https://www.strava.com/api/v3/segments/2803641/leaderboard
# segment 2803641, num efforts 266 pages 2
# total time 0.07 min
# Num done 184
# https://www.strava.com/api/v3/segments/11796086/leaderboard
# segment 11796086, num efforts 118 pages 1
# total time 0.03 min
# Num done 185
# https://www.strava.com/api/v3/segments/4183207/leaderboard
# segment 4183207, num efforts 2224 pages 12
# total time 0.50 min
# Num done 186
# https://www.strava.com/api/v3/segments/1501368/leaderboard
# segment 1501368, num efforts 2807 pages 15
# total time 0.62 min
# Num done 187
# https://www.strava.com/api/v3/segments/2226472/leaderboard
# segment 2226472, num efforts 1535 pages 8
# total time 0.30 min
# Num done 188
# https://www.strava.com/api/v3/segments/8984941/leaderboard
# segment 8984941, num efforts 1144 pages 6
# total time 0.24 min
# Num done 189
# https://www.strava.com/api/v3/segments/1541057/leaderboard
# segment 1541057, num efforts 2228 pages 12
# total time 0.43 min
# Num done 190
# https://www.strava.com/api/v3/segments/3932195/leaderboard
# segment 3932195, num efforts 697 pages 4
# total time 0.16 min
# Num done 191
# https://www.strava.com/api/v3/segments/1393438/leaderboard
# segment 1393438, num efforts 1269 pages 7
# total time 0.25 min
# Num done 192
# https://www.strava.com/api/v3/segments/6581209/leaderboard
# segment 6581209, num efforts 89 pages 1
# total time 0.03 min
# Num done 193
# https://www.strava.com/api/v3/segments/1752830/leaderboard
# segment 1752830, num efforts 2001 pages 11
# total time 0.49 min
# Num done 194
# https://www.strava.com/api/v3/segments/9768609/leaderboard
# segment 9768609, num efforts 453 pages 3
# total time 0.11 min
# Num done 195
# https://www.strava.com/api/v3/segments/12573928/leaderboard
# segment 12573928, num efforts 2045 pages 11
# total time 0.45 min
# Num done 196
# https://www.strava.com/api/v3/segments/4751535/leaderboard
# segment 4751535, num efforts 349 pages 2
# total time 0.09 min
# Num done 197
# https://www.strava.com/api/v3/segments/7812524/leaderboard
# segment 7812524, num efforts 1949 pages 10
# total time 0.39 min
# Num done 198
# https://www.strava.com/api/v3/segments/4480066/leaderboard
# segment 4480066, num efforts 1925 pages 10
# total time 0.38 min
# Num done 199
# https://www.strava.com/api/v3/segments/1393436/leaderboard
# segment 1393436, num efforts 1956 pages 10
# total time 0.36 min
# Num done 200
# https://www.strava.com/api/v3/segments/1358020/leaderboard
# segment 1358020, num efforts 479 pages 3
# total time 0.11 min
# Num done 1
# https://www.strava.com/api/v3/segments/5369641/leaderboard
# segment 5369641, num efforts 246 pages 2
# total time 0.07 min
# Num done 2
# https://www.strava.com/api/v3/segments/2594791/leaderboard
# segment 2594791, num efforts 215 pages 2
# total time 0.07 min
# Num done 3
# https://www.strava.com/api/v3/segments/7926258/leaderboard
# segment 7926258, num efforts 129 pages 1
# total time 0.04 min
# Num done 4
# https://www.strava.com/api/v3/segments/5184446/leaderboard
# segment 5184446, num efforts 133 pages 1
# total time 0.03 min
# Num done 5
# https://www.strava.com/api/v3/segments/7828029/leaderboard
# segment 7828029, num efforts 707 pages 4
# total time 0.16 min
# Num done 6
# https://www.strava.com/api/v3/segments/3621050/leaderboard
# segment 3621050, num efforts 562 pages 3
# total time 0.11 min
# Num done 7
# https://www.strava.com/api/v3/segments/1291699/leaderboard
# segment 1291699, num efforts 531 pages 3
# total time 0.11 min
# Num done 8
# https://www.strava.com/api/v3/segments/1249950/leaderboard
# segment 1249950, num efforts 652 pages 4
# total time 0.14 min
# Num done 9
# https://www.strava.com/api/v3/segments/5556629/leaderboard
# segment 5556629, num efforts 675 pages 4
# total time 0.16 min
# Num done 10
# https://www.strava.com/api/v3/segments/12607934/leaderboard
# segment 12607934, num efforts 58 pages 1
# total time 0.03 min
# Num done 11
# https://www.strava.com/api/v3/segments/2035987/leaderboard
# segment 2035987, num efforts 174 pages 1
# total time 0.04 min
# Num done 12
# https://www.strava.com/api/v3/segments/10471384/leaderboard
# segment 10471384, num efforts 750 pages 4
# total time 0.16 min
# Num done 13
# https://www.strava.com/api/v3/segments/9881025/leaderboard
# segment 9881025, num efforts 316 pages 2
# total time 0.08 min
# Num done 14
# https://www.strava.com/api/v3/segments/2186676/leaderboard
# segment 2186676, num efforts 367 pages 2
# total time 0.08 min
# Num done 15
# https://www.strava.com/api/v3/segments/7148870/leaderboard
# segment 7148870, num efforts 276 pages 2
# total time 0.07 min
# Num done 16
# https://www.strava.com/api/v3/segments/7291997/leaderboard
# segment 7291997, num efforts 659 pages 4
# total time 0.15 min
# Num done 17
# https://www.strava.com/api/v3/segments/7164013/leaderboard
# segment 7164013, num efforts 1434 pages 8
# total time 0.32 min
# Num done 18
# https://www.strava.com/api/v3/segments/10361413/leaderboard
# segment 10361413, num efforts 406 pages 3
# total time 0.11 min
# Num done 19
# https://www.strava.com/api/v3/segments/7990937/leaderboard
# segment 7990937, num efforts 419 pages 3
# total time 0.11 min
# Num done 20
# https://www.strava.com/api/v3/segments/723067/leaderboard
# segment 723067, num efforts 1396 pages 7
# total time 0.26 min
# Num done 21
# https://www.strava.com/api/v3/segments/5234273/leaderboard
# segment 5234273, num efforts 373 pages 2
# total time 0.07 min
# Num done 22
# https://www.strava.com/api/v3/segments/827910/leaderboard
# segment 827910, num efforts 778 pages 4
# total time 0.16 min
# Num done 23
# https://www.strava.com/api/v3/segments/1722742/leaderboard
# segment 1722742, num efforts 1817 pages 10
# total time 0.41 min
# Num done 24
# https://www.strava.com/api/v3/segments/1248458/leaderboard
# segment 1248458, num efforts 804 pages 5
# total time 0.19 min
# Num done 25
# https://www.strava.com/api/v3/segments/7754293/leaderboard
# segment 7754293, num efforts 1058 pages 6
# total time 0.24 min
# Num done 26
# https://www.strava.com/api/v3/segments/1464466/leaderboard
# segment 1464466, num efforts 316 pages 2
# total time 0.08 min
# Num done 27
# https://www.strava.com/api/v3/segments/723071/leaderboard
# segment 723071, num efforts 1038 pages 6
# total time 0.23 min
# Num done 28
# https://www.strava.com/api/v3/segments/14913206/leaderboard
# segment 14913206, num efforts 334 pages 2
# total time 0.07 min
# Num done 29
# https://www.strava.com/api/v3/segments/4354134/leaderboard
# segment 4354134, num efforts 796 pages 4
# total time 0.17 min
# Num done 30
# https://www.strava.com/api/v3/segments/4354133/leaderboard
# segment 4354133, num efforts 677 pages 4
# total time 0.14 min
# Num done 31
# https://www.strava.com/api/v3/segments/10060074/leaderboard
# segment 10060074, num efforts 543 pages 3
# total time 0.11 min
# Num done 32
# https://www.strava.com/api/v3/segments/4499369/leaderboard
# segment 4499369, num efforts 337 pages 2
# total time 0.07 min
# Num done 33
# https://www.strava.com/api/v3/segments/1476784/leaderboard
# segment 1476784, num efforts 780 pages 4
# total time 0.16 min
# Num done 34
# https://www.strava.com/api/v3/segments/5176674/leaderboard
# segment 5176674, num efforts 172 pages 1
# total time 0.04 min
# Num done 35
# https://www.strava.com/api/v3/segments/1754828/leaderboard
# segment 1754828, num efforts 655 pages 4
# total time 0.15 min
# Num done 36
# https://www.strava.com/api/v3/segments/7577717/leaderboard
# segment 7577717, num efforts 1105 pages 6
# total time 0.24 min
# Num done 37
# https://www.strava.com/api/v3/segments/1624455/leaderboard
# segment 1624455, num efforts 713 pages 4
# total time 0.15 min
# Num done 38
# https://www.strava.com/api/v3/segments/956928/leaderboard
# segment 956928, num efforts 381 pages 2
# total time 0.08 min
# Num done 39
# https://www.strava.com/api/v3/segments/5094650/leaderboard
# segment 5094650, num efforts 73 pages 1
# total time 0.03 min
# Num done 40
# https://www.strava.com/api/v3/segments/5101838/leaderboard
# segment 5101838, num efforts 36 pages 1
# total time 0.03 min
# Num done 41
# https://www.strava.com/api/v3/segments/9120548/leaderboard
# segment 9120548, num efforts 20 pages 1
# total time 0.03 min
# Num done 42
# https://www.strava.com/api/v3/segments/2589941/leaderboard
# segment 2589941, num efforts 75 pages 1
# total time 0.03 min
# Num done 43
# https://www.strava.com/api/v3/segments/1617380/leaderboard
# segment 1617380, num efforts 79 pages 1
# total time 0.03 min
# Num done 44
# https://www.strava.com/api/v3/segments/2514752/leaderboard
# segment 2514752, num efforts 28 pages 1
# total time 0.03 min
# Num done 45
# https://www.strava.com/api/v3/segments/16738239/leaderboard
# segment 16738239, num efforts 2205 pages 12
# total time 0.46 min
# Num done 46
# https://www.strava.com/api/v3/segments/2986083/leaderboard
# segment 2986083, num efforts 325 pages 2
# total time 0.07 min
# Num done 47
# https://www.strava.com/api/v3/segments/1457970/leaderboard
# segment 1457970, num efforts 528 pages 3
# total time 0.11 min
# Num done 48
# https://www.strava.com/api/v3/segments/1457973/leaderboard
# segment 1457973, num efforts 444 pages 3
# total time 0.10 min
# Num done 49
# https://www.strava.com/api/v3/segments/5317686/leaderboard
# segment 5317686, num efforts 387 pages 2
# total time 0.07 min
# Num done 50
# https://www.strava.com/api/v3/segments/3538707/leaderboard
# segment 3538707, num efforts 292 pages 2
# total time 0.07 min
# Num done 51
# https://www.strava.com/api/v3/segments/6156466/leaderboard
# segment 6156466, num efforts 358 pages 2
# total time 0.07 min
# Num done 52
# https://www.strava.com/api/v3/segments/2151944/leaderboard
# segment 2151944, num efforts 302 pages 2
# total time 0.07 min
# Num done 53
# https://www.strava.com/api/v3/segments/3950422/leaderboard
# segment 3950422, num efforts 183 pages 1
# total time 0.04 min
# Num done 54
# https://www.strava.com/api/v3/segments/1184458/leaderboard
# segment 1184458, num efforts 567 pages 3
# total time 0.13 min
# Num done 55
# https://www.strava.com/api/v3/segments/3626495/leaderboard
# segment 3626495, num efforts 2448 pages 13
# total time 0.53 min
# Num done 56
# https://www.strava.com/api/v3/segments/1105149/leaderboard
# segment 1105149, num efforts 1903 pages 10
# total time 0.41 min
# Num done 57
# https://www.strava.com/api/v3/segments/4014830/leaderboard
# segment 4014830, num efforts 1405 pages 8
# total time 0.31 min
# Num done 58
# https://www.strava.com/api/v3/segments/6547824/leaderboard
# segment 6547824, num efforts 2467 pages 13
# total time 0.48 min
# Num done 59
# https://www.strava.com/api/v3/segments/14630743/leaderboard
# segment 14630743, num efforts 2017 pages 11
# total time 0.38 min
# Num done 60
# https://www.strava.com/api/v3/segments/6528805/leaderboard
# segment 6528805, num efforts 472 pages 3
# total time 0.12 min
# Num done 61
# https://www.strava.com/api/v3/segments/9032070/leaderboard
# segment 9032070, num efforts 2026 pages 11
# total time 0.42 min
# Num done 62
# https://www.strava.com/api/v3/segments/1402894/leaderboard
# segment 1402894, num efforts 1301 pages 7
# total time 0.29 min
# Num done 63
# https://www.strava.com/api/v3/segments/16860303/leaderboard
# segment 16860303, num efforts 222 pages 2
# total time 0.07 min
# Num done 64
# https://www.strava.com/api/v3/segments/2827015/leaderboard
# segment 2827015, num efforts 1324 pages 7
# total time 0.26 min
# Num done 65
# https://www.strava.com/api/v3/segments/7895072/leaderboard
# segment 7895072, num efforts 2267 pages 12
# total time 0.50 min
# Num done 66
# https://www.strava.com/api/v3/segments/3603166/leaderboard
# segment 3603166, num efforts 1681 pages 9
# total time 0.38 min
# Num done 67
# https://www.strava.com/api/v3/segments/2317575/leaderboard
# segment 2317575, num efforts 1499 pages 8
# total time 0.32 min
# Num done 68
# https://www.strava.com/api/v3/segments/3211611/leaderboard
# segment 3211611, num efforts 670 pages 4
# total time 0.15 min
# Num done 69
# https://www.strava.com/api/v3/segments/2687422/leaderboard
# segment 2687422, num efforts 675 pages 4
# total time 0.16 min
# Num done 70
# https://www.strava.com/api/v3/segments/1217671/leaderboard
# segment 1217671, num efforts 1658 pages 9
# total time 0.35 min
# Num done 71
# https://www.strava.com/api/v3/segments/16514931/leaderboard
# segment 16514931, num efforts 1238 pages 7
# total time 0.27 min
# Num done 72
# https://www.strava.com/api/v3/segments/1393650/leaderboard
# segment 1393650, num efforts 698 pages 4
# total time 0.15 min
# Num done 73
# https://www.strava.com/api/v3/segments/14506130/leaderboard
# segment 14506130, num efforts 1524 pages 8
# total time 0.30 min
# Num done 74
# https://www.strava.com/api/v3/segments/1395997/leaderboard
# segment 1395997, num efforts 1205 pages 7
# total time 0.24 min
# Num done 75
# https://www.strava.com/api/v3/segments/5812403/leaderboard
# segment 5812403, num efforts 5523 pages 28
# total time 1.17 min
# Num done 76
# https://www.strava.com/api/v3/segments/1740276/leaderboard
# segment 1740276, num efforts 1478 pages 8
# total time 0.33 min
# Num done 77
# https://www.strava.com/api/v3/segments/1097491/leaderboard
# segment 1097491, num efforts 2268 pages 12
# total time 0.52 min
# Num done 78
# https://www.strava.com/api/v3/segments/1281485/leaderboard
# segment 1281485, num efforts 1036 pages 6
# total time 0.23 min
# Num done 79
# https://www.strava.com/api/v3/segments/3914062/leaderboard
# segment 3914062, num efforts 609 pages 4
# total time 0.16 min
# Num done 80
# https://www.strava.com/api/v3/segments/8250979/leaderboard
# segment 8250979, num efforts 935 pages 5
# total time 0.20 min
# Num done 81
# https://www.strava.com/api/v3/segments/6528404/leaderboard
# segment 6528404, num efforts 473 pages 3
# total time 0.11 min
# Num done 82
# https://www.strava.com/api/v3/segments/8748197/leaderboard
# segment 8748197, num efforts 172 pages 1
# total time 0.04 min
# Num done 83
# https://www.strava.com/api/v3/segments/7349217/leaderboard
# segment 7349217, num efforts 432 pages 3
# total time 0.11 min
# Num done 84
# https://www.strava.com/api/v3/segments/1207256/leaderboard
# segment 1207256, num efforts 1960 pages 10
# total time 0.42 min
# Num done 85
# https://www.strava.com/api/v3/segments/1740384/leaderboard
# segment 1740384, num efforts 1950 pages 10
# total time 0.43 min
# Num done 86
# https://www.strava.com/api/v3/segments/5822469/leaderboard
# segment 5822469, num efforts 405 pages 3
# total time 0.11 min
# Num done 87
# https://www.strava.com/api/v3/segments/10044815/leaderboard
# segment 10044815, num efforts 153 pages 1
# total time 0.04 min
# Num done 88
# https://www.strava.com/api/v3/segments/746797/leaderboard
# segment 746797, num efforts 443 pages 3
# total time 0.12 min
# Num done 89
# https://www.strava.com/api/v3/segments/746883/leaderboard
# segment 746883, num efforts 219 pages 2
# total time 0.06 min
# Num done 90
# https://www.strava.com/api/v3/segments/8735101/leaderboard
# segment 8735101, num efforts 70 pages 1
# total time 0.03 min
# Num done 91
# https://www.strava.com/api/v3/segments/3105485/leaderboard
# segment 3105485, num efforts 12 pages 1
# total time 0.03 min
# Num done 92
# https://www.strava.com/api/v3/segments/3614144/leaderboard
# segment 3614144, num efforts 64 pages 1
# total time 0.03 min
# Num done 93
# https://www.strava.com/api/v3/segments/14470350/leaderboard
# segment 14470350, num efforts 219 pages 2
# total time 0.06 min
# Num done 94
# https://www.strava.com/api/v3/segments/2640081/leaderboard
# segment 2640081, num efforts 157 pages 1
# total time 0.04 min
# Num done 95
# https://www.strava.com/api/v3/segments/2433056/leaderboard
# segment 2433056, num efforts 12 pages 1
# total time 0.03 min
# Num done 96
# https://www.strava.com/api/v3/segments/4968082/leaderboard
# segment 4968082, num efforts 85 pages 1
# total time 0.03 min
# Num done 97
# https://www.strava.com/api/v3/segments/11146986/leaderboard
# segment 11146986, num efforts 24 pages 1
# total time 0.03 min
# Num done 98
# https://www.strava.com/api/v3/segments/6047913/leaderboard
# segment 6047913, num efforts 17 pages 1
# total time 0.03 min
# Num done 99
# https://www.strava.com/api/v3/segments/8853662/leaderboard
# segment 8853662, num efforts 61 pages 1
# total time 0.03 min
# Num done 100
# https://www.strava.com/api/v3/segments/5259295/leaderboard
# segment 5259295, num efforts 76 pages 1
# total time 0.03 min
# Num done 101
# https://www.strava.com/api/v3/segments/2347929/leaderboard
# segment 2347929, num efforts 57 pages 1
# total time 0.03 min
# Num done 102
# https://www.strava.com/api/v3/segments/14423439/leaderboard
# segment 14423439, num efforts 22 pages 1
# total time 0.03 min
# Num done 103
# https://www.strava.com/api/v3/segments/2308814/leaderboard
# segment 2308814, num efforts 61 pages 1
# total time 0.03 min
# Num done 104
# https://www.strava.com/api/v3/segments/2308812/leaderboard
# segment 2308812, num efforts 54 pages 1
# total time 0.03 min
# Num done 105
# https://www.strava.com/api/v3/segments/10139759/leaderboard
# segment 10139759, num efforts 59 pages 1
# total time 0.03 min
# Num done 106
# https://www.strava.com/api/v3/segments/9115723/leaderboard
# segment 9115723, num efforts 42 pages 1
# total time 0.03 min
# Num done 107
# https://www.strava.com/api/v3/segments/6804474/leaderboard
# segment 6804474, num efforts 35 pages 1
# total time 0.03 min
# Num done 108
# https://www.strava.com/api/v3/segments/2362721/leaderboard
# segment 2362721, num efforts 32 pages 1
# total time 0.03 min
# Num done 109
# https://www.strava.com/api/v3/segments/2362933/leaderboard
# segment 2362933, num efforts 35 pages 1
# total time 0.03 min
# Num done 110
# https://www.strava.com/api/v3/segments/16671137/leaderboard
# segment 16671137, num efforts 10 pages 1
# total time 0.03 min
# Num done 111
# https://www.strava.com/api/v3/segments/14477251/leaderboard
# segment 14477251, num efforts 45 pages 1
# total time 0.03 min
# Num done 112
# https://www.strava.com/api/v3/segments/14477265/leaderboard
# segment 14477265, num efforts 33 pages 1
# total time 0.03 min
# Num done 113
# https://www.strava.com/api/v3/segments/16558032/leaderboard
# segment 16558032, num efforts 17 pages 1
# total time 0.03 min
# Num done 114
# https://www.strava.com/api/v3/segments/4580627/leaderboard
# segment 4580627, num efforts 59 pages 1
# total time 0.03 min
# Num done 115
# https://www.strava.com/api/v3/segments/7105845/leaderboard
# segment 7105845, num efforts 618 pages 4
# total time 0.15 min
# Num done 116
# https://www.strava.com/api/v3/segments/1353851/leaderboard
# segment 1353851, num efforts 541 pages 3
# total time 0.10 min
# Num done 117
# https://www.strava.com/api/v3/segments/9977100/leaderboard
# segment 9977100, num efforts 57 pages 1
# total time 0.03 min
# Num done 118
# https://www.strava.com/api/v3/segments/9976133/leaderboard
# segment 9976133, num efforts 50 pages 1
# total time 0.03 min
# Num done 119
# https://www.strava.com/api/v3/segments/6319205/leaderboard
# segment 6319205, num efforts 24 pages 1
# total time 0.03 min
# Num done 120
# https://www.strava.com/api/v3/segments/5006019/leaderboard
# segment 5006019, num efforts 61 pages 1
# total time 0.03 min
# Num done 121
# https://www.strava.com/api/v3/segments/673251/leaderboard
# segment 673251, num efforts 4240 pages 22
# total time 1.00 min
# Num done 122
# https://www.strava.com/api/v3/segments/749649/leaderboard
# segment 749649, num efforts 5411 pages 28
# total time 1.22 min
# Num done 123
# https://www.strava.com/api/v3/segments/4279044/leaderboard
# segment 4279044, num efforts 4986 pages 25
# total time 1.03 min
# Num done 124
# https://www.strava.com/api/v3/segments/7173810/leaderboard
# segment 7173810, num efforts 5719 pages 29
# total time 1.13 min
# Num done 125
# https://www.strava.com/api/v3/segments/7495081/leaderboard
# segment 7495081, num efforts 5757 pages 29
# total time 1.08 min
# Num done 126
# https://www.strava.com/api/v3/segments/11692448/leaderboard
# segment 11692448, num efforts 5974 pages 30
# total time 1.15 min
# Num done 127
# https://www.strava.com/api/v3/segments/1740626/leaderboard
# segment 1740626, num efforts 6077 pages 31
# total time 1.24 min
# Num done 128
# https://www.strava.com/api/v3/segments/941570/leaderboard
# segment 941570, num efforts 5524 pages 28
# total time 1.27 min
# Num done 129
# https://www.strava.com/api/v3/segments/4880942/leaderboard
# segment 4880942, num efforts 6047 pages 31
# total time 1.22 min
# Num done 130
# https://www.strava.com/api/v3/segments/749692/leaderboard
# segment 749692, num efforts 2876 pages 15
# total time 0.62 min
# Num done 131
# https://www.strava.com/api/v3/segments/12229145/leaderboard
# segment 12229145, num efforts 11194 pages 56
# total time 2.68 min
# Num done 132
# https://www.strava.com/api/v3/segments/685327/leaderboard
# segment 685327, num efforts 8051 pages 41
# total time 1.79 min
# Num done 133
# https://www.strava.com/api/v3/segments/729514/leaderboard
# segment 729514, num efforts 11389 pages 57
# total time 2.50 min
# Num done 134
# https://www.strava.com/api/v3/segments/1677960/leaderboard
# segment 1677960, num efforts 11397 pages 57
# total time 2.28 min
# Num done 135
# https://www.strava.com/api/v3/segments/12266765/leaderboard
# segment 12266765, num efforts 8752 pages 44
# total time 1.76 min
# Num done 136
# https://www.strava.com/api/v3/segments/15598263/leaderboard
# segment 15598263, num efforts 4392 pages 22
# total time 0.88 min
# Num done 137
# https://www.strava.com/api/v3/segments/15640495/leaderboard
# segment 15640495, num efforts 7661 pages 39
# total time 1.42 min
# Num done 138
# https://www.strava.com/api/v3/segments/13260637/leaderboard
# segment 13260637, num efforts 4453 pages 23
# total time 0.87 min
# Num done 139
# https://www.strava.com/api/v3/segments/5210407/leaderboard
# segment 5210407, num efforts 4423 pages 23
# total time 0.95 min
# Num done 140
# https://www.strava.com/api/v3/segments/5210384/leaderboard
# segment 5210384, num efforts 4301 pages 22
# total time 0.85 min
# Num done 141
# https://www.strava.com/api/v3/segments/2223014/leaderboard
# segment 2223014, num efforts 1036 pages 6
# total time 0.24 min
# Num done 142
# https://www.strava.com/api/v3/segments/10556215/leaderboard
# segment 10556215, num efforts 263 pages 2
# total time 0.07 min
# Num done 143
# https://www.strava.com/api/v3/segments/4754422/leaderboard
# segment 4754422, num efforts 39 pages 1
# total time 0.03 min
# Num done 144
# https://www.strava.com/api/v3/segments/6496243/leaderboard
# segment 6496243, num efforts 36 pages 1
# total time 0.03 min
# Num done 145
# https://www.strava.com/api/v3/segments/4948434/leaderboard
# segment 4948434, num efforts 59 pages 1
# total time 0.03 min
# Num done 146
# https://www.strava.com/api/v3/segments/4711240/leaderboard
# segment 4711240, num efforts 132 pages 1
# total time 0.04 min
# Num done 147
# https://www.strava.com/api/v3/segments/4891116/leaderboard
# segment 4891116, num efforts 93 pages 1
# total time 0.03 min
# Num done 148
# https://www.strava.com/api/v3/segments/8763147/leaderboard
# segment 8763147, num efforts 278 pages 2
# total time 0.06 min
# Num done 149
# https://www.strava.com/api/v3/segments/14634245/leaderboard
# segment 14634245, num efforts 51 pages 1
# total time 0.03 min
# Num done 150
# https://www.strava.com/api/v3/segments/9537989/leaderboard
# segment 9537989, num efforts 27 pages 1
# total time 0.03 min
# Num done 151
# https://www.strava.com/api/v3/segments/4852201/leaderboard
# segment 4852201, num efforts 362 pages 2
# total time 0.08 min
# Num done 152
# https://www.strava.com/api/v3/segments/3360306/leaderboard
# segment 3360306, num efforts 397 pages 2
# total time 0.07 min
# Num done 153
# https://www.strava.com/api/v3/segments/2217573/leaderboard
# segment 2217573, num efforts 1469 pages 8
# total time 0.32 min
# Num done 154
# https://www.strava.com/api/v3/segments/1539798/leaderboard
# segment 1539798, num efforts 377 pages 2
# total time 0.07 min
# Num done 155
# https://www.strava.com/api/v3/segments/1945633/leaderboard
# segment 1945633, num efforts 458 pages 3
# total time 0.11 min
# Num done 156
# https://www.strava.com/api/v3/segments/680820/leaderboard
# segment 680820, num efforts 1078 pages 6
# total time 0.24 min
# Num done 157
# https://www.strava.com/api/v3/segments/680821/leaderboard
# segment 680821, num efforts 1031 pages 6
# total time 0.22 min
# Num done 158
# https://www.strava.com/api/v3/segments/1436352/leaderboard
# segment 1436352, num efforts 881 pages 5
# total time 0.20 min
# Num done 159
# https://www.strava.com/api/v3/segments/16273743/leaderboard
# segment 16273743, num efforts 11 pages 1
# total time 0.03 min
# Num done 160
# https://www.strava.com/api/v3/segments/5863298/leaderboard
# segment 5863298, num efforts 11 pages 1
# total time 0.03 min
# Num done 161
# ...
# total time 0.22 min
# Num done 40
# https://www.strava.com/api/v3/segments/1065239/leaderboard
# segment 1065239, num efforts 2520 pages 13
# total time 0.56 min
# Num done 41
# https://www.strava.com/api/v3/segments/15450657/leaderboard
# segment 15450657, num efforts 819 pages 5
# total time 0.19 min
# Num done 42
# https://www.strava.com/api/v3/segments/4841951/leaderboard
# segment 4841951, num efforts 1677 pages 9
# total time 0.36 min
# Num done 43
# https://www.strava.com/api/v3/segments/4787229/leaderboard
# segment 4787229, num efforts 2225 pages 12
# total time 0.45 min
# Num done 44
# https://www.strava.com/api/v3/segments/7869415/leaderboard
# segment 7869415, num efforts 1662 pages 9
# total time 0.36 min
# Num done 45
# https://www.strava.com/api/v3/segments/2070653/leaderboard
# segment 2070653, num efforts 1718 pages 9
# total time 0.33 min
# Num done 46
# https://www.strava.com/api/v3/segments/12516250/leaderboard
# segment 12516250, num efforts 223 pages 2
# total time 0.07 min
# Num done 47
# https://www.strava.com/api/v3/segments/6221240/leaderboard
# segment 6221240, num efforts 2563 pages 13
# total time 0.69 min
# Num done 48
# https://www.strava.com/api/v3/segments/3898891/leaderboard
# segment 3898891, num efforts 410 pages 3
# total time 0.13 min
# Num done 49
# https://www.strava.com/api/v3/segments/866710/leaderboard
# segment 866710, num efforts 3568 pages 18
# total time 0.92 min
# Num done 50
# https://www.strava.com/api/v3/segments/887104/leaderboard
# segment 887104, num efforts 442 pages 3
# total time 0.12 min
# Num done 51
# https://www.strava.com/api/v3/segments/1551356/leaderboard
# segment 1551356, num efforts 221 pages 2
# total time 0.07 min
# Num done 52
# https://www.strava.com/api/v3/segments/1190951/leaderboard
# segment 1190951, num efforts 561 pages 3
# total time 0.11 min
# Num done 53
# https://www.strava.com/api/v3/segments/7154740/leaderboard
# segment 7154740, num efforts 1283 pages 7
# total time 0.28 min
# Num done 54
# https://www.strava.com/api/v3/segments/1157563/leaderboard
# segment 1157563, num efforts 239 pages 2
# total time 0.09 min
# Num done 55
# https://www.strava.com/api/v3/segments/1190950/leaderboard
# segment 1190950, num efforts 1328 pages 7
# total time 0.28 min
# Num done 56
# https://www.strava.com/api/v3/segments/1157564/leaderboard
# segment 1157564, num efforts 238 pages 2
# total time 0.09 min
# Num done 57
# https://www.strava.com/api/v3/segments/4246808/leaderboard
# segment 4246808, num efforts 102 pages 1
# total time 0.03 min
# Num done 58
# https://www.strava.com/api/v3/segments/4003659/leaderboard
# segment 4003659, num efforts 515 pages 3
# total time 0.12 min
# Num done 59
# https://www.strava.com/api/v3/segments/7288514/leaderboard
# segment 7288514, num efforts 153 pages 1
# total time 0.04 min
# Num done 60
# https://www.strava.com/api/v3/segments/7284796/leaderboard
# segment 7284796, num efforts 113 pages 1
# total time 0.04 min
# Num done 61
# https://www.strava.com/api/v3/segments/4497698/leaderboard
# segment 4497698, num efforts 224 pages 2
# total time 0.09 min
# Num done 62
# https://www.strava.com/api/v3/segments/4497694/leaderboard
# segment 4497694, num efforts 169 pages 1
# total time 0.04 min
# Num done 63
# https://www.strava.com/api/v3/segments/10446037/leaderboard
# segment 10446037, num efforts 140 pages 1
# total time 0.04 min
# Num done 64
# https://www.strava.com/api/v3/segments/9546286/leaderboard
# segment 9546286, num efforts 225 pages 2
# total time 0.07 min
# Num done 65
# https://www.strava.com/api/v3/segments/6680177/leaderboard
# segment 6680177, num efforts 494 pages 3
# total time 0.12 min
# Num done 66
# https://www.strava.com/api/v3/segments/9778506/leaderboard
# segment 9778506, num efforts 428 pages 3
# total time 0.10 min
# Num done 67
# https://www.strava.com/api/v3/segments/7859772/leaderboard
# segment 7859772, num efforts 184 pages 1
# total time 0.04 min
# Num done 68
# https://www.strava.com/api/v3/segments/1396629/leaderboard
# segment 1396629, num efforts 915 pages 5
# total time 0.25 min
# Num done 69
# https://www.strava.com/api/v3/segments/5078211/leaderboard
# segment 5078211, num efforts 677 pages 4
# total time 0.20 min
# Num done 70
# https://www.strava.com/api/v3/segments/10515263/leaderboard
# segment 10515263, num efforts 113 pages 1
# total time 0.05 min
# Num done 71
# https://www.strava.com/api/v3/segments/4002827/leaderboard
# segment 4002827, num efforts 1192 pages 6
# total time 0.28 min
# Num done 72
# https://www.strava.com/api/v3/segments/2076335/leaderboard
# segment 2076335, num efforts 1313 pages 7
# total time 0.28 min
# Num done 73
# https://www.strava.com/api/v3/segments/1367842/leaderboard
# segment 1367842, num efforts 715 pages 4
# total time 0.16 min
# Num done 74
# https://www.strava.com/api/v3/segments/9638693/leaderboard
# segment 9638693, num efforts 58 pages 1
# total time 0.03 min
# Num done 75
# https://www.strava.com/api/v3/segments/1886987/leaderboard
# segment 1886987, num efforts 151 pages 1
# total time 0.04 min
# Num done 76
# https://www.strava.com/api/v3/segments/2994943/leaderboard
# segment 2994943, num efforts 210 pages 2
# total time 0.07 min
# Num done 77
# https://www.strava.com/api/v3/segments/1134858/leaderboard
# segment 1134858, num efforts 585 pages 3
# total time 0.14 min
# Num done 78
# https://www.strava.com/api/v3/segments/1293804/leaderboard
# segment 1293804, num efforts 603 pages 4
# total time 0.14 min
# Num done 79
# https://www.strava.com/api/v3/segments/4317279/leaderboard
# segment 4317279, num efforts 78 pages 1
# total time 0.03 min
# Num done 80
# https://www.strava.com/api/v3/segments/7408809/leaderboard
# segment 7408809, num efforts 20 pages 1
# total time 0.03 min
# Num done 81
# https://www.strava.com/api/v3/segments/4402298/leaderboard
# segment 4402298, num efforts 163 pages 1
# total time 0.04 min
# Num done 82
# https://www.strava.com/api/v3/segments/4854545/leaderboard
# segment 4854545, num efforts 146 pages 1
# total time 0.04 min
# Num done 83
# https://www.strava.com/api/v3/segments/1755404/leaderboard
# segment 1755404, num efforts 180 pages 1
# total time 0.04 min
# Num done 84
# https://www.strava.com/api/v3/segments/1755406/leaderboard
# segment 1755406, num efforts 180 pages 1
# total time 0.03 min
# Num done 85
# https://www.strava.com/api/v3/segments/15344758/leaderboard
# segment 15344758, num efforts 53 pages 1
# total time 0.03 min
# Num done 86
# https://www.strava.com/api/v3/segments/15345959/leaderboard
# segment 15345959, num efforts 164 pages 1
# total time 0.04 min
# Num done 87
# https://www.strava.com/api/v3/segments/5039488/leaderboard
# segment 5039488, num efforts 33 pages 1
# total time 0.03 min
# Num done 88
# https://www.strava.com/api/v3/segments/15233506/leaderboard
# segment 15233506, num efforts 11 pages 1
# total time 0.03 min
# Num done 89
# https://www.strava.com/api/v3/segments/1755410/leaderboard
# segment 1755410, num efforts 38 pages 1
# total time 0.03 min
# Num done 90
# https://www.strava.com/api/v3/segments/7898116/leaderboard
# segment 7898116, num efforts 33 pages 1
# total time 0.03 min
# Num done 91
# https://www.strava.com/api/v3/segments/3549760/leaderboard
# segment 3549760, num efforts 1677 pages 9
# total time 0.40 min
# Num done 92
# https://www.strava.com/api/v3/segments/6954509/leaderboard
# segment 6954509, num efforts 308 pages 2
# total time 0.08 min
# Num done 93
# https://www.strava.com/api/v3/segments/1150297/leaderboard
# segment 1150297, num efforts 1716 pages 9
# total time 0.34 min
# Num done 94
# https://www.strava.com/api/v3/segments/8527213/leaderboard
# segment 8527213, num efforts 300 pages 2
# total time 0.08 min
# Num done 95
# https://www.strava.com/api/v3/segments/5605632/leaderboard
# segment 5605632, num efforts 119 pages 1
# total time 0.04 min
# Num done 96
# https://www.strava.com/api/v3/segments/3634829/leaderboard
# segment 3634829, num efforts 612 pages 4
# total time 0.14 min
# Num done 97
# https://www.strava.com/api/v3/segments/1367821/leaderboard
# segment 1367821, num efforts 356 pages 2
# total time 0.08 min
# Num done 98
# https://www.strava.com/api/v3/segments/12009653/leaderboard
# segment 12009653, num efforts 160 pages 1
# total time 0.04 min
# Num done 99
# https://www.strava.com/api/v3/segments/14090528/leaderboard
# segment 14090528, num efforts 709 pages 4
# total time 0.15 min
# Num done 100
# https://www.strava.com/api/v3/segments/12966256/leaderboard
# segment 12966256, num efforts 57 pages 1
# total time 0.03 min
# Num done 101
# https://www.strava.com/api/v3/segments/7817143/leaderboard
# segment 7817143, num efforts 329 pages 2
# total time 0.08 min
# Num done 102
# https://www.strava.com/api/v3/segments/11157711/leaderboard
# segment 11157711, num efforts 310 pages 2
# total time 0.11 min
# Num done 103
# https://www.strava.com/api/v3/segments/1264819/leaderboard
# segment 1264819, num efforts 1682 pages 9
# total time 0.38 min
# Num done 104
# https://www.strava.com/api/v3/segments/1756226/leaderboard
# segment 1756226, num efforts 396 pages 2
# total time 0.08 min
# Num done 105
# https://www.strava.com/api/v3/segments/7519044/leaderboard
# segment 7519044, num efforts 209 pages 2
# total time 0.07 min
# Num done 106
# https://www.strava.com/api/v3/segments/3848421/leaderboard
# segment 3848421, num efforts 110 pages 1
# total time 0.03 min
# Num done 107
# https://www.strava.com/api/v3/segments/5668203/leaderboard
# segment 5668203, num efforts 568 pages 3
# total time 0.13 min
# Num done 108
# https://www.strava.com/api/v3/segments/992396/leaderboard
# segment 992396, num efforts 980 pages 5
# total time 0.22 min
# Num done 109
# https://www.strava.com/api/v3/segments/6767715/leaderboard
# segment 6767715, num efforts 214 pages 2
# total time 0.09 min
# Num done 110
# https://www.strava.com/api/v3/segments/1889329/leaderboard
# segment 1889329, num efforts 130 pages 1
# total time 0.04 min
# Num done 111
# https://www.strava.com/api/v3/segments/17011312/leaderboard
# segment 17011312, num efforts 369 pages 2
# total time 0.08 min
# Num done 112
# https://www.strava.com/api/v3/segments/5668202/leaderboard
# segment 5668202, num efforts 1639 pages 9
# total time 0.40 min
# Num done 113
# https://www.strava.com/api/v3/segments/1604773/leaderboard
# segment 1604773, num efforts 178 pages 1
# total time 0.04 min
# Num done 114
# https://www.strava.com/api/v3/segments/14171945/leaderboard
# segment 14171945, num efforts 87 pages 1
# total time 0.04 min
# Num done 115
# https://www.strava.com/api/v3/segments/918220/leaderboard
# segment 918220, num efforts 1588 pages 8
# total time 0.37 min
# Num done 116
# https://www.strava.com/api/v3/segments/12581816/leaderboard
# segment 12581816, num efforts 28 pages 1
# total time 0.03 min
# Num done 117
# https://www.strava.com/api/v3/segments/16360416/leaderboard
# segment 16360416, num efforts 20 pages 1
# total time 0.03 min
# Num done 118
# https://www.strava.com/api/v3/segments/6334881/leaderboard
# segment 6334881, num efforts 20 pages 1
# total time 0.03 min
# Num done 119
# https://www.strava.com/api/v3/segments/5883863/leaderboard
# segment 5883863, num efforts 29 pages 1
# total time 0.03 min
# Num done 120
# https://www.strava.com/api/v3/segments/1604774/leaderboard
# segment 1604774, num efforts 88 pages 1
# total time 0.03 min
# Num done 121
# https://www.strava.com/api/v3/segments/10798653/leaderboard
# segment 10798653, num efforts 3156 pages 16
# total time 0.70 min
# Num done 122
# https://www.strava.com/api/v3/segments/10663144/leaderboard
# segment 10663144, num efforts 2568 pages 13
# total time 0.55 min
# Num done 123
# https://www.strava.com/api/v3/segments/9258303/leaderboard
# segment 9258303, num efforts 2100 pages 11
# total time 0.49 min
# Num done 124
# https://www.strava.com/api/v3/segments/1774910/leaderboard
# segment 1774910, num efforts 471 pages 3
# total time 0.12 min
# Num done 125
# https://www.strava.com/api/v3/segments/10839348/leaderboard
# segment 10839348, num efforts 579 pages 3
# total time 0.13 min
# Num done 126
# https://www.strava.com/api/v3/segments/12327844/leaderboard
# segment 12327844, num efforts 584 pages 3
# total time 0.13 min
# Num done 127
# https://www.strava.com/api/v3/segments/4160933/leaderboard
# segment 4160933, num efforts 193 pages 1
# total time 0.04 min
# Num done 128
# https://www.strava.com/api/v3/segments/7039313/leaderboard
# segment 7039313, num efforts 343 pages 2
# total time 0.08 min
# Num done 129
# https://www.strava.com/api/v3/segments/1117437/leaderboard
# segment 1117437, num efforts 177 pages 1
# total time 0.04 min
# Num done 130
# https://www.strava.com/api/v3/segments/5582256/leaderboard
# segment 5582256, num efforts 261 pages 2
# total time 0.08 min
# Num done 131
# https://www.strava.com/api/v3/segments/3583597/leaderboard
# segment 3583597, num efforts 5236 pages 27
# total time 1.29 min
# Num done 132
# https://www.strava.com/api/v3/segments/4580643/leaderboard
# segment 4580643, num efforts 4822 pages 25
# total time 1.16 min
# Num done 133
# https://www.strava.com/api/v3/segments/12445708/leaderboard
# segment 12445708, num efforts 1334 pages 7
# total time 0.29 min
# Num done 134
# https://www.strava.com/api/v3/segments/4580644/leaderboard
# segment 4580644, num efforts 1924 pages 10
# total time 0.44 min
# Num done 135
# https://www.strava.com/api/v3/segments/3718337/leaderboard
# segment 3718337, num efforts 1775 pages 9
# total time 0.39 min
# Num done 136
# https://www.strava.com/api/v3/segments/1221497/leaderboard
# segment 1221497, num efforts 1973 pages 10
# total time 0.47 min
# Num done 137
# https://www.strava.com/api/v3/segments/17183819/leaderboard
# segment 17183819, num efforts 314 pages 2
# total time 0.08 min
# Num done 138
# https://www.strava.com/api/v3/segments/1141848/leaderboard
# segment 1141848, num efforts 189 pages 1
# total time 0.04 min
# Num done 139
# https://www.strava.com/api/v3/segments/1791404/leaderboard
# segment 1791404, num efforts 86 pages 1
# total time 0.04 min
# Num done 140
# https://www.strava.com/api/v3/segments/13755418/leaderboard
# segment 13755418, num efforts 13 pages 1
# total time 0.03 min
# Num done 141
# https://www.strava.com/api/v3/segments/1253091/leaderboard
# segment 1253091, num efforts 3822 pages 20
# total time 0.95 min
# Num done 142
# https://www.strava.com/api/v3/segments/6594338/leaderboard
# segment 6594338, num efforts 2330 pages 12
# total time 0.52 min
# Num done 143
# https://www.strava.com/api/v3/segments/1299935/leaderboard
# segment 1299935, num efforts 2926 pages 15
# total time 0.68 min
# Num done 144
# https://www.strava.com/api/v3/segments/2552392/leaderboard
# segment 2552392, num efforts 4156 pages 21
# total time 0.97 min
# Num done 145
# https://www.strava.com/api/v3/segments/5361441/leaderboard
# segment 5361441, num efforts 3444 pages 18
# total time 0.75 min
# Num done 146
# https://www.strava.com/api/v3/segments/2141393/leaderboard
# segment 2141393, num efforts 1755 pages 9
# total time 0.40 min
# Num done 147
# https://www.strava.com/api/v3/segments/2552390/leaderboard
# segment 2552390, num efforts 3883 pages 20
# total time 0.83 min
# Num done 148
# https://www.strava.com/api/v3/segments/14798007/leaderboard
# segment 14798007, num efforts 1764 pages 9
# total time 0.45 min
# Num done 149
# https://www.strava.com/api/v3/segments/2704930/leaderboard
# segment 2704930, num efforts 1262 pages 7
# total time 0.30 min
# Num done 150
# https://www.strava.com/api/v3/segments/1891861/leaderboard
# segment 1891861, num efforts 792 pages 4
# total time 0.18 min
# Num done 151
# https://www.strava.com/api/v3/segments/1277853/leaderboard
# segment 1277853, num efforts 5090 pages 26
# total time 1.25 min
# Num done 152
# https://www.strava.com/api/v3/segments/3287685/leaderboard
# segment 3287685, num efforts 4068 pages 21
# total time 1.06 min
# Num done 153
# https://www.strava.com/api/v3/segments/1336742/leaderboard
# segment 1336742, num efforts 2813 pages 15
# total time 0.69 min
# Num done 154
# https://www.strava.com/api/v3/segments/886879/leaderboard
# segment 886879, num efforts 3341 pages 17
# total time 0.75 min
# Num done 155
# https://www.strava.com/api/v3/segments/3962536/leaderboard
# segment 3962536, num efforts 1866 pages 10
# total time 0.43 min
# Num done 156
# https://www.strava.com/api/v3/segments/1281610/leaderboard
# segment 1281610, num efforts 2171 pages 11
# total time 0.71 min
# Num done 12
# https://www.strava.com/api/v3/segments/4169471/leaderboard
# segment 4169471, num efforts 1311 pages 7
# total time 0.31 min
# Num done 13
# https://www.strava.com/api/v3/segments/6801481/leaderboard
# segment 6801481, num efforts 1029 pages 6
# total time 0.25 min
# Num done 14
# https://www.strava.com/api/v3/segments/2551466/leaderboard
# segment 2551466, num efforts 3067 pages 16

# %%
activities = pd.DataFrame()
max_frames = 50
for i in range(0, max_frames):
    activities = activities.append(pd.read_csv("strava-activities-italy-full-{}.csv".format(i)))

# %%
#save activities
activities.to_csv(path_or_buf="strava-activities-italy-full-FINAL.csv",index=True)
